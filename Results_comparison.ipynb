# %%
import pandas as pd

# %%
results = pd.read_csv("results.csv")

# %%
results1 = pd.read_csv("results1.csv")

# %%
results2 = pd.read_csv("results2.csv")

# %%
results3 = pd.read_csv("results3.csv")

# %%
results4 = pd.read_csv("results4.csv")

# %%
results = pd.concat([results,results1,results2,results3,results4],axis = 0,ignore_index = True)

# %%
results
# Out:
#    Unnamed: 0                                              model  Accuracy  \
# 0           0  Pipeline(memory=None,\n         steps=[('norm'...  0.871892
# 1           1  Pipeline(memory=None,\n         steps=[('norm'...  0.871892
# 2           0  Pipeline(memory=None,\n         steps=[('norm'...  0.847628
# 3           1  Pipeline(memory=None,\n         steps=[('norm'...  0.886932
# 4           0  Pipeline(memory=None,\n         steps=[('norm'...  0.872862
# 5           0  Pipeline(memory=None,\n         steps=[('norm'...  0.914315
# 6           0  Pipeline(memory=None,\n         steps=[('norm'...  0.873459
#
#    PrecisionLab1  RecallLab1  FMeasureLab1       AUC
# 0       0.871892    1.000000      0.931562  0.796662
# 1       0.871892    1.000000      0.931562  0.816064
# 2       0.912017    0.913905      0.912960  0.732623
# 3       0.903464    0.974855      0.937803  0.814607
# 4       0.873334    0.999278      0.932071 -1.000000
# ...

# %%
results = results.drop(['Unnamed: 0'],axis = 1)

# %%
results.insert(1,"Model",['DecisionTreeClassifier','BaggingClassifier','GuassianNB','LogisticRegression','RidgeClassifier','XGBClassifier','RandomForestClassifier'],True)

# %%
results
# Out:
#                                                model                   Model  \
# 0  Pipeline(memory=None,\n         steps=[('norm'...  DecisionTreeClassifier
# 1  Pipeline(memory=None,\n         steps=[('norm'...       BaggingClassifier
# 2  Pipeline(memory=None,\n         steps=[('norm'...              GuassianNB
# 3  Pipeline(memory=None,\n         steps=[('norm'...      LogisticRegression
# 4  Pipeline(memory=None,\n         steps=[('norm'...         RidgeClassifier
# 5  Pipeline(memory=None,\n         steps=[('norm'...           XGBClassifier
# 6  Pipeline(memory=None,\n         steps=[('norm'...  RandomForestClassifier
#
#    Accuracy  PrecisionLab1  RecallLab1  FMeasureLab1       AUC
# 0  0.871892       0.871892    1.000000      0.931562  0.796662
# 1  0.871892       0.871892    1.000000      0.931562  0.816064
# 2  0.847628       0.912017    0.913905      0.912960  0.732623
# 3  0.886932       0.903464    0.974855      0.937803  0.814607
# ...

# %%
results = results.drop(['model'],axis = 1)

# %%
results
# Out:
#                     Model  Accuracy  PrecisionLab1  RecallLab1  FMeasureLab1  \
# 0  DecisionTreeClassifier  0.871892       0.871892    1.000000      0.931562
# 1       BaggingClassifier  0.871892       0.871892    1.000000      0.931562
# 2              GuassianNB  0.847628       0.912017    0.913905      0.912960
# 3      LogisticRegression  0.886932       0.903464    0.974855      0.937803
# 4         RidgeClassifier  0.872862       0.873334    0.999278      0.932071
# 5           XGBClassifier  0.914315       0.924398    0.982202      0.952424
# 6  RandomForestClassifier  0.873459       0.873554    0.999852      0.932446
#
#         AUC
# 0  0.796662
# 1  0.816064
# 2  0.732623
# 3  0.814607
# 4 -1.000000
# 5  0.898465
# 6  0.809022
