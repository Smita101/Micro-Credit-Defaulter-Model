# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import dfply as dp
import random
import warnings
from sklearn import datasets
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.pipeline import Pipeline
from mlxtend.feature_selection import SequentialFeatureSelector
from mlxtend.plotting import plot_sequential_feature_selection
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from mlxtend.classifier import StackingClassifier
from sklearn.metrics.classification import precision_score, recall_score
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve, confusion_matrix
from keras import Sequential
from sklearn.ensemble import VotingClassifier
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
data = pd.read_csv(r"C:\Users\Administrator\Downloads\Micro-Credit-Project\Data file.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# 1             12.0                 0.0          1.0            12
# 2              6.0                 0.0          1.0             6
# 3              6.0                 0.0          2.0            12
# 4              6.0                 0.0          7.0            42
#
#    maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                6                 0.0  29.000000  29.000000      UPW
# 1               12                 0.0   0.000000   0.000000      UPW
# 2                6                 0.0   0.000000   0.000000      UPW
# 3                6                 0.0   0.000000   0.000000      UPW
# 4                6                 0.0   2.333333   2.333333      UPW
#
#         pdate
# 0  2016-07-20
# 1  2016-08-10
# 2  2016-08-19
# 3  2016-06-06
# 4  2016-06-22
#
# [5 rows x 37 columns]

# %%
data.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                  object
# pdate                    object
# dtype: object

# %%
data.shape
# Out:
# (209593, 37)

# %%
index_names = data[ data['cnt_loans30'] == 0 ].index
data.drop(index_names, inplace = True)

# %%
index_names1 = data[ data['cnt_loans90'] == 0 ].index
data.drop(index_names1,inplace = True)

# %%
data.shape
# Out:
# (206334, 37)

# %%
data = data.rename(columns = {'Unnamed: 0':'Customer_number'},inplace = False)

# %%
data.set_index('Customer_number',inplace = True)

# %%
data.skew(axis = 0)
# Out:
# label                   -2.243226
# aon                     10.412316
# daily_decr30             3.965795
# daily_decr90             4.284159
# rental30                 4.468993
# rental90                 4.379261
# last_rech_date_ma       14.802413
# last_rech_date_da       14.763021
# last_rech_amt_ma         3.838389
# cnt_ma_rech30            3.276838
# fr_ma_rech30            14.800651
# sumamnt_ma_rech30        6.402651
# medianamnt_ma_rech30     3.553197
# medianmarechprebal30    14.778444
# cnt_ma_rech90            3.427664
# fr_ma_rech90             2.290585
# sumamnt_ma_rech90        4.923172
# medianamnt_ma_rech90     3.799376
# medianmarechprebal90    45.512392
# cnt_da_rech30           17.803363
# fr_da_rech30            14.764186
# cnt_da_rech90           27.137861
# fr_da_rech90            28.775577
# cnt_loans30              2.737129
# amnt_loans30             2.997192
# maxamnt_loans30         17.648609
# medianamnt_loans30       4.510679
# cnt_loans90             16.573289
# amnt_loans90             3.145134
# maxamnt_loans90          2.216911
# medianamnt_loans90       4.877133
# payback30                8.265049
# payback90                6.897933
# dtype: float64

# %%
data = data.drop(['msisdn','pcircle','pdate'],axis = 1)

# %%
x_data = data.drop(['label'],axis =1)
y_data = data['label']

# %%
from skew_autotransform import skew_autotransform

# %%
skew_autotransform(x_data, include = None, exclude = None, plot = False, threshold = 1, exp = False)
# Out:
#                       aon  daily_decr30  daily_decr90   rental30   rental90  \
# Customer_number
# 1                5.007875      7.063366      6.857964  13.727007  11.583752
# 2                5.641413      8.076737      7.802499  13.971596  11.751494
# 3                5.450142      6.484916      6.310847  13.777442  11.616678
# 4                4.931418      4.382941      4.305022  13.722439  11.578496
# 5                5.833189      5.021444      4.918549  13.791938  11.626742
# ...                   ...           ...           ...        ...        ...
# 209589           5.264127      5.025714      4.922639  13.791232  11.626252
# 209590           5.918487      4.492695      4.410740  13.837131  11.658119
# 209591           5.878522      8.059856      7.790136  14.110120  11.971470
# 209592           6.238448      8.098310      7.827016  13.741360  11.620963
# 209593           6.177444      7.348562      7.130078  13.746730  11.602941
#
#                  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# Customer_number
# 1                         2.868565           1.986364         31.624181
# 2                         3.176564           1.986364         50.836330
# 3                         2.890417           1.986364         31.624181
# 4                         3.406182           1.986364         26.450913
# 5                         2.911526           1.986364         36.636475
# ...                            ...                ...               ...
# 209589                    2.845917           1.986364         44.791346
# 209590                    2.911526           1.986364         24.524225
# 209591                    2.890417           1.986364         31.624181
# 209592                    2.868565           2.212258         24.524225
# 209593                    3.074556           1.986364         55.762990
#
#                  cnt_ma_rech30  fr_ma_rech30  ...  cnt_loans30  amnt_loans30  \
# Customer_number                               ...
# 1                     0.793481      2.993640  ...     0.589553      1.551326
# 2                     0.009968     -4.726050  ...     0.000000      1.551326
# 3                     0.009968     -4.726050  ...     0.000000      1.264623
# 4                    -2.251392     -4.726050  ...     0.589553      1.551326
# 5                     2.819470      0.695411  ...     1.264243      1.900247
# ...                        ...           ...  ...          ...           ...
# 209589                1.351915      0.695411  ...     0.589553      1.551326
# 209590                1.800809      0.009950  ...     0.853629      1.684589
# 209591                2.182549      2.056625  ...     1.012133      1.900247
# 209592                2.182549      1.378042  ...     0.589553      1.684589
# 209593                0.793481      0.009950  ...     0.589553      1.684589
#
#                  maxamnt_loans30  medianamnt_loans30  cnt_loans90  \
# Customer_number
# 1                       0.136433       -1.666328e+06     0.600292
# 2                       0.136433       -1.666328e+06     0.000000
# 3                       0.136433       -1.666328e+06     0.000000
# 4                       0.136433       -1.666328e+06     0.600292
# 5                       0.136433       -1.666328e+06     1.323383
# ...                          ...                 ...          ...
# 209589                  0.136433       -1.666328e+06     0.600292
# 209590                  0.136433       -1.666328e+06     0.877601
# 209591                  0.136433       -1.666328e+06     1.253765
# 209592                  0.136433       -1.666328e+06     0.877601
# 209593                  0.136433       -1.666328e+06     0.600292
#
#                  amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# Customer_number
# 1                    1.700162         0.089546       -2.098241e+07   3.113993
# 2                    1.700162         0.089546       -2.098241e+07  -5.143115
# 3                    1.355357         0.089546       -2.098241e+07  -5.143115
# 4                    1.700162         0.089546       -2.098241e+07  -5.143115
# 5                    2.155489         0.089546       -2.098241e+07   0.834712
# ...                       ...              ...                 ...        ...
# 209589               1.700162         0.089546       -2.098241e+07   0.009948
# 209590               1.868410         0.089546       -2.098241e+07   0.009948
# 209591               2.226409         0.089546       -2.098241e+07   1.344317
# 209592               1.974934         0.089546       -2.098241e+07  -5.143115
# 209593               1.868410         0.089546       -2.098241e+07  -5.143115
#
#                  payback90
# Customer_number
# 1                 3.483684
# 2                -4.399384
# 3                -4.399384
# 4                -4.399384
# 5                 0.858870
# ...                    ...
# 209589            0.009951
# 209590            0.009951
# 209591            1.364637
# 209592            2.408561
# 209593           -4.399384
#
# [206334 rows x 32 columns]

# %%
X = x_data
Y = y_data
size = 0.3

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=size)

# %%
def create_pipeline(norm, model):
    if norm == 1:
        scale = StandardScaler()
        pipe = Pipeline([('norm', scale), ('reg', model)])
    elif norm == 2:
        scale = MinMaxScaler()
        pipe = Pipeline([('norm', scale), ('reg', model)])
    else:
        pipe = Pipeline([('reg', model)])
    return pipe

# %%
def select_features(model, X_train, Y_train, selection,
                    score_criteria, see_details, norm=0):
    pipe = create_pipeline(norm, model)
    sfs = SequentialFeatureSelector(pipe,
                                    forward=selection,
                                    k_features= 11,
                                    scoring=score_criteria,
                                    verbose=see_details)
    sfs = sfs.fit(X_train, Y_train)
    return list(sfs.k_feature_idx_)

# %%
def run_model(model, param_grid, X_train, Y_train,
              X, Y, score_criteria, folds,
              see_details, norm=0):
    pipe = create_pipeline(norm, model)
    model_grid = GridSearchCV(pipe,
                              param_grid,
                              cv=folds,
                              scoring=score_criteria,
                              verbose=see_details)
    model_grid.fit(X_train, Y_train)

    pipe = create_pipeline(norm, model_grid.best_estimator_)
    return model_grid.best_estimator_

# %%
def get_model_eval(model, X_train, Y_train, X_test, Y_test):
    cm = confusion_matrix(Y_test, model.predict(X_test))
    t1, f1, t0, f0 = cm[1, 1], cm[1, 0], cm[0, 0], cm[0, 1]
    precision = precision_score(Y_test, model.predict(X_test))
    recall = recall_score(Y_test, model.predict(X_test))
    return pd.Series([model,
                      (t1 + t0) / (t1 + t0 + f1 + f0),
                      precision,
                      recall,
                      2 * precision * recall / (precision + recall),
                      -1 if type(model.steps[1][1]) == RidgeClassifier else roc_auc_score(Y_test, model.predict_proba(X_test)[:, 1])])

# %%
PARAM_DICT = {
  LogisticRegression: {
    'reg__tol': [1e-2, 1e-4, 1e-6],
    'reg__fit_intercept': [True, False],
    'reg__penalty': ['l1', 'l2']
  },
  RidgeClassifier: {
    'reg__alpha': [0.1, 1, 100],
    'reg__copy_X': [True, False],
    'reg__fit_intercept': [True, False],
    'reg__tol': [0.1, 1],
    'reg__solver': ['auto', 'svd', 'cholesky', 'lsqr',
      'sparse_cg', 'sag', 'saga'
    ]
  },

  KNeighborsClassifier: {
    'reg__n_neighbors': [5, 30, 100]
  },
  GaussianNB: {
  },

  DecisionTreeClassifier: {
    'reg__max_depth': [5, 10, 20],
    'reg__max_features': [0.3, 0.7, 1.0],
    'reg__max_leaf_nodes': [10, 50, 100],
    'reg__splitter': ['best', 'random']
  },

  BaggingClassifier: {
    'reg__bootstrap': [True, False],
    'reg__bootstrap_features': [True, False],
    'reg__max_features': [0.3, 0.7, 1.0],
    'reg__max_samples': [0.3, 0.7, 1.0],
    'reg__n_estimators': [10, 50, 100]
  },
  RandomForestClassifier: {
    'reg__bootstrap': [True, False],
    'reg__max_depth': [5, 10, 20],
    'reg__max_features': [0.3, 0.7, 1.0],
    'reg__max_leaf_nodes': [10, 50, 100],
    'reg__min_impurity_decrease': [0, 0.1, 0.2],
    'reg__n_estimators': [10, 50, 100]
  },

  SVC: {
    'reg__C': [10 ** -3, 1, 1000],
    'reg__kernel': ['linear', 'poly', 'rbf'],
    'reg__shrinking': [True, False],
    'reg__probability': [True]
  },

  GradientBoostingClassifier: {
    'reg__learning_rate': [0.1, 0.2, 0.5],
    # 'reg__loss': ['ls', 'lad', 'huber', 'quantile'],
    'reg__max_depth': [10, 20, 50],
    'reg__max_features': [0.5, 0.8, 1.0],
    'reg__max_leaf_nodes': [10, 50, 100],
    'reg__min_impurity_decrease': [0, 0.1, 0.2],
    'reg__min_samples_leaf': [5, 10, 20],
    'reg__min_samples_split': [5, 10, 20],
    'reg__n_estimators': [10, 50, 100]
  },
  XGBClassifier: {
    'reg__booster': ['gbtree', 'gblinear', 'dart'],
    'reg__learning_rate': [0.2, 0.5, 0.8],
    'reg__max_depth': [5, 10, 20],
    'reg__n_estimators': [10, 50, 100],
    'reg__reg_alpha': [0.1, 1, 10],
    'reg__reg_lambda': [0.1, 1, 10],
    'reg__subsample': [0.3, 0.5, 0.8],
    'reg__probability': [True]
  }
}

# %%
random.seed(100)
norm = 1
folds = 4
score_criteria = 'f1'
see_details = 2

# %%
results = pd.DataFrame(columns=['model', 'Accuracy', 'PrecisionLab1', 'RecallLab1',
                                'FMeasureLab1', 'AUC'])

# %%
   
to_run = [RandomForestClassifier,
          GradientBoostingClassifier]

# %%
for model in to_run:
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        best_feat = select_features(model(), X_train, Y_train, True,
                                    score_criteria, see_details, norm)
        model = run_model(model(), PARAM_DICT[model],
                          X_train.iloc[:, best_feat],
                          Y_train,
                          X.iloc[:, best_feat], Y,
                          score_criteria, folds, see_details, norm)
        stats = get_model_eval(model, X_train.iloc[:, best_feat], Y_train,
                               X_test.iloc[:, best_feat], Y_test)
        stats.index = results.columns
        results = results.append(stats, ignore_index=True)
print(results)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 45.3min finished
#
# [2020-09-25 12:59:24] Features: 1/11 -- score: 0.9322535097497419[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 34.9min finished
#
# [2020-09-25 13:34:18] Features: 2/11 -- score: 0.9322535097497419[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 51.6min finished
#
# [2020-09-25 14:25:54] Features: 3/11 -- score: 0.9322535097497419[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 42.2min finished
#
# [2020-09-25 15:08:05] Features: 4/11 -- score: 0.9322495629281397[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 39.8min finished
#
# [2020-09-25 15:47:50] Features: 5/11 -- score: 0.9322214332064123[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 41.9min finished
#
# [2020-09-25 16:29:46] Features: 6/11 -- score: 0.9321670332247111[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 48.6min finished
#
# [2020-09-25 17:18:21] Features: 7/11 -- score: 0.9321230962753072[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 35.3min finished
#
# [2020-09-25 17:53:39] Features: 8/11 -- score: 0.9321230978009151[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 38.9min finished
#
# [2020-09-25 18:32:35] Features: 9/11 -- score: 0.9321004144590399[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 42.1min finished
#
# [2020-09-25 19:14:42] Features: 10/11 -- score: 0.9320408085407269[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 43.1min finished
#
# [2020-09-25 19:57:46] Features: 11/11 -- score: 0.9320047510565688[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 4 folds for each of 486 candidates, totalling 1944 fits
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   2.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   2.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   2.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   2.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.2s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.2s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.1s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   3.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   3.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   3.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   3.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   3.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   3.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   6.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   2.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   3.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   3.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   2.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   5.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   2.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.4s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.3, reg__max_leaf_nodes=100, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   2.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   0.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   3.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   3.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   3.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=50, total=   4.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   8.1s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   7.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   8.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__n_estimators=100, total=   7.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=10, total=   0.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=50, total=   1.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   3.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   3.8s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   3.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__n_estimators=100, total=   3.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=10, total=   0.5s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=50, total=   1.9s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   3.7s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   3.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   3.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.2, reg__n_estimators=100, total=   3.6s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   1.0s
# [CV] reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10
# [CV]  reg__bootstrap=True, reg__max_depth=5, reg__max_features=0.7, reg__max_leaf_nodes=50, reg__min_impurity_decrease=0, reg__n_estimators=10, total=   1.0s
# ...
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=50, total=  17.2s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=50
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=50, total=  23.5s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=100
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=100, total=  44.4s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=100
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=100, total=  34.8s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=100
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=100, total=  37.9s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=100
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0, reg__min_samples_leaf=20, reg__min_samples_split=20, reg__n_estimators=100, total=  30.8s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=10
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=10, total=   4.0s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=10
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=10, total=   3.7s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=10
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=10, total=   3.3s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=10
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=10, total=   3.2s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=50
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=50, total=  16.5s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=50
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=50, total=  16.6s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=50
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=50, total=  16.0s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=50
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=50, total=  16.2s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=100
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=100, total=  29.7s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=100
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=100, total=  42.1s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=100
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=100, total=  33.7s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=100
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=5, reg__n_estimators=100, total=  29.7s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=10, reg__n_estimators=10
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=10, reg__n_estimators=10, total=   3.1s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=10, reg__n_estimators=10
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=10, reg__n_estimators=10, total=   3.2s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=10, reg__n_estimators=10
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=10, reg__n_estimators=10, total=   3.3s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=10, reg__n_estimators=10
# [CV]  reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=10, reg__n_estimators=10, total=   3.4s
# [CV] reg__learning_rate=0.1, reg__max_depth=20, reg__max_features=0.8, reg__max_leaf_nodes=10, reg__min_impurity_decrease=0.1, reg__min_samples_leaf=5, reg__min_samples_split=10, reg__n_estimators=50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-85f85e921574> in <module>
#       8                           Y_train,
#       9                           X.iloc[:, best_feat], Y,
# ---> 10                           score_criteria, folds, see_details, norm)
#      11         stats = get_model_eval(model, X_train.iloc[:, best_feat], Y_train,
#      12                                X_test.iloc[:, best_feat], Y_test)
#
# <ipython-input-20-b37cfc89f748> in run_model(model, param_grid, X_train, Y_train, X, Y, score_criteria, folds, see_details, norm)
#       8                               scoring=score_criteria,
#       9                               verbose=see_details)
# ---> 10     model_grid.fit(X_train, Y_train)
#      11
#      12     pipe = create_pipeline(norm, model_grid.best_estimator_)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     352                                  self._log_message(len(self.steps) - 1)):
#     353             if self._final_estimator != 'passthrough':
# --> 354                 self._final_estimator.fit(Xt, y, **fit_params)
#     355         return self
#     356
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#    1535         n_stages = self._fit_stages(
#    1536             X, y, raw_predictions, sample_weight, self._rng, X_val, y_val,
# -> 1537             sample_weight_val, begin_at_stage, monitor, X_idx_sorted)
#    1538
#    1539         # change shape of arrays after fit (early-stopping or additional ests)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor, X_idx_sorted)
#    1592             raw_predictions = self._fit_stage(
#    1593                 i, X, y, raw_predictions, sample_weight, sample_mask,
# -> 1594                 random_state, X_idx_sorted, X_csc, X_csr)
#    1595
#    1596             # track deviance (= loss)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#    1243             X = X_csr if X_csr is not None else X
#    1244             tree.fit(X, residual, sample_weight=sample_weight,
# -> 1245                      check_input=False, X_idx_sorted=X_idx_sorted)
#    1246
#    1247             # update tree leaves
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1223             sample_weight=sample_weight,
#    1224             check_input=check_input,
# -> 1225             X_idx_sorted=X_idx_sorted)
#    1226         return self
#    1227
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     365                                            min_impurity_split)
#     366
# --> 367         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     368
#     369         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
results
# Out:
#                                                model  Accuracy  PrecisionLab1  \
# 0  (StandardScaler(copy=True, with_mean=True, wit...  0.873459       0.873554
#
#    RecallLab1  FMeasureLab1       AUC
# 0    0.999852      0.932446  0.809022

# %%
results.to_csv("results4.csv")
